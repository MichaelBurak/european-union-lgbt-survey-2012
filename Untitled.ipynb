# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Very-interesting-to-see-'average'-as-a-value" data-toc-modified-id="Very-interesting-to-see-'average'-as-a-value-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Very interesting to see 'average' as a value</a></span></li></ul></div>

# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('LGBT_Survey_TransgenderSpecificQuestions.csv')

df.head(10)
# Out:
#   CountryCode       subset question_code  \
# 0     Austria  Transgender           tr1
# 1     Austria  Transgender           tr1
# 2     Austria  Transgender           tr1
# 3     Belgium  Transgender           tr1
# 4     Belgium  Transgender           tr1
# 5     Belgium  Transgender           tr1
# 6    Bulgaria  Transgender           tr1
# 7    Bulgaria  Transgender           tr1
# 8    Bulgaria  Transgender           tr1
# 9      Cyprus  Transgender           tr1
#
#                                       question_label      answer percentage  \
# 0  Have you ever sought psychological or medical ...         Yes         35
# 1  Have you ever sought psychological or medical ...          No         60
# 2  Have you ever sought psychological or medical ...  Don`t know          5
# 3  Have you ever sought psychological or medical ...         Yes         48
# 4  Have you ever sought psychological or medical ...          No         37
# ...

# %%
len(df)
# Out:
# 3421

# %% [markdown]
# ## Very interesting to see 'average' as a value

# %%
sns.countplot(y=df['CountryCode'])

# %%
df.CountryCode.value_counts()
# Out:
# Germany           120
# United Kingdom    120
# France            120
# Spain             120
# Hungary           120
# Italy             120
# Czech Republic    120
# Greece            120
# Sweden            120
# Lithuania         120
# Poland            120
# Ireland           120
# Average           120
# Belgium           120
# Finland           119
# Netherlands       119
# Slovakia          119
# Denmark           119
# Austria           119
# Romania           119
# Latvia            118
# Portugal          117
# Croatia           116
# Bulgaria          116
# Luxembourg        115
# Cyprus            113
# Malta             112
# Estonia           111
# Slovenia          109
# Name: CountryCode, dtype: int64

# %%
df.question_code.value_counts()
# Out:
# tr3      475
# tr2      336
# tr6_b    174
# tr6_d    174
# tr6_g    174
# tr6_f    174
# tr6_e    174
# tr6_h    174
# tr6_a    174
# tr6_c    174
# tr5      145
# tr7      116
# tr8_h     87
# tr1       87
# tr8_g     87
# tr8_d     87
# tr9       87
# tr8_a     87
# tr8_c     87
# tr8_f     87
# tr8_b     87
# tr8_e     87
# tr4       87
# Name: question_code, dtype: int64

# %%
display(df.question_label.value_counts())
# Out:
# From whom did you seek help and what was the outcome? *                                                                                                                                                                                                             475
# Why haven`t you ever sought psychological or medical help for being a transgender person?                                                                                                                                                                           336
# Easier legal procedures for gender recognition in the preferred gender - What would allow you to be more comfortable living as a transgender person in the country where you live?                                                                                  174
# ...

# %%
df.notes.value_counts(dropna=False)
# Out:
# [0]      1649
# NaN      1402
#  [1]      370
# Name: notes, dtype: int64

# %%
dfnotes = df[df['notes'] == " [1] "]

dfnotes.head(20)
# Out:
#     CountryCode       subset question_code  \
# 57        Malta  Transgender           tr1
# 58        Malta  Transgender           tr1
# 59        Malta  Transgender           tr1
# 169     Estonia  Transgender           tr2
# 170     Estonia  Transgender           tr2
# 171     Estonia  Transgender           tr2
# 172     Estonia  Transgender           tr2
# 173     Estonia  Transgender           tr2
# 174     Estonia  Transgender           tr2
# 175     Estonia  Transgender           tr2
# 176     Estonia  Transgender           tr2
# 177     Estonia  Transgender           tr2
# 178     Estonia  Transgender           tr2
# 179     Estonia  Transgender           tr2
# 306       Malta  Transgender           tr2
# 307       Malta  Transgender           tr2
# 308       Malta  Transgender           tr2
# 309       Malta  Transgender           tr2
# 310       Malta  Transgender           tr2
# 311       Malta  Transgender           tr2
#
# ...

# %%
highest_question = df[df['question_code'] == 'tr3']

highest_question
# Out:
#     CountryCode       subset question_code  \
# 423     Austria  Transgender           tr3
# 424     Austria  Transgender           tr3
# 425     Austria  Transgender           tr3
# 426     Austria  Transgender           tr3
# 427     Austria  Transgender           tr3
# ..          ...          ...           ...
# 893     Average  Transgender           tr3
# 894     Average  Transgender           tr3
# 895     Average  Transgender           tr3
# 896     Average  Transgender           tr3
# 897     Average  Transgender           tr3
#
#                                         question_label  \
# 423  From whom did you seek help and what was the o...
# 424  From whom did you seek help and what was the o...
# 425  From whom did you seek help and what was the o...
# 426  From whom did you seek help and what was the o...
# 427  From whom did you seek help and what was the o...
# ..                                                 ...
# ...

# %%
highest_question.answer.value_counts()
# Out:
# A) Was informative and helpful                                        29
# B) Wanted to help but could not offer everything I needed             29
# B) Was informative and helpful                                        29
# A) Does not apply to me                                               28
# C) Was informative and helpful                                        28
# B) Wanted to help, but I did not consent to the treatment proposed    28
# C) Does not apply to me                                               28
# B) Does not apply to me                                               27
# B) Did not seem to want to help me                                    27
# C) Wanted to help but could not offer everything I needed             27
# C) Did not seem to want to help me                                    26
# A) Did not seem to want to help me                                    26
# A) Wanted to help, but I did not consent to the treatment proposed    26
# ...

# %%
seeking_help_df = df[df['question_label'] == "Why haven`t you ever sought psychological or medical help for being a transgender person?"]

seeking_help_df.head(10)
# Out:
#    CountryCode       subset question_code  \
# 87     Austria  Transgender           tr2
# 88     Austria  Transgender           tr2
# 89     Austria  Transgender           tr2
# 90     Austria  Transgender           tr2
# 91     Austria  Transgender           tr2
# 92     Austria  Transgender           tr2
# 93     Austria  Transgender           tr2
# 94     Austria  Transgender           tr2
# 95     Austria  Transgender           tr2
# 96     Austria  Transgender           tr2
#
#                                        question_label  \
# 87  Why haven`t you ever sought psychological or m...
# 88  Why haven`t you ever sought psychological or m...
# 89  Why haven`t you ever sought psychological or m...
# 90  Why haven`t you ever sought psychological or m...
# 91  Why haven`t you ever sought psychological or m...
# 92  Why haven`t you ever sought psychological or m...
# 93  Why haven`t you ever sought psychological or m...
# 94  Why haven`t you ever sought psychological or m...
# ...

# %%
seeking_help_df.answer.value_counts()
# Out:
# Other                                                        29
# I do not have confidence in the services provided            29
# I do not want / need help                                    29
# It takes too much time (including waiting lists)             29
# It is not covered by my country`s public health insurance    29
# I do not dare to                                             29
# I cannot afford it due to financial reasons                  28
# I do not know where to go                                    28
# I am afraid of prejudice from the care providers             28
# It is too complicated in terms of bureaucracy                28
# It is not available in the country where you live            25
# I have had previous bad experiences with care providers      25
# Name: answer, dtype: int64
